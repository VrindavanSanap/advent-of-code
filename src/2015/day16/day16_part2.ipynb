# %%
with open("./src/2015/day16/2015_day16.txt") as f:
	lines = f.read().split("\n")

# %%
gift_sue = {"children": 3, 
"cats": 7, 
"samoyeds": 2, 
"pomeranians": 3, 
"akitas": 0, 
"vizslas": 0,
"goldfish": 5,
"trees": 3,
"cars": 2,
"perfumes": 1}

# %%
for line in lines:
	line = line.split()
	sue_no  = line[1].strip(':')
	attr1 = line[2].strip(':')
	attr2 = line[4].strip(':')
	attr3 = line[6].strip(':')
	attr1_value = int(line[3].strip(','))
	attr2_value =  int(line[5].strip(','))
	attr3_value = int(line[7].strip(','))
	attrs = {attr1: attr1_value, attr2: attr2_value, attr3:attr3_value}
	


	attr1_gt= gift_sue[attr1]
	attr2_gt= gift_sue[attr2]
	attr3_gt= gift_sue[attr3]
	succ = True
	for attr in attrs: 
		if attr == "cats" or attr == "trees":
			if gift_sue[attr]	 < attrs[attr]:
				pass 
			else:
				succ = False
				break
		elif (attr == "pomeranians" or attr == "goldfish"):
			if gift_sue[attr]	 > attrs[attr]:
				pass 
			else:
				succ = False
				break
		else:
			if gift_sue[attr]	== attrs[attr]:
				pass 
			else:
				succ = False
				break
				
	if (succ):
		print(sue_no)
		break
# Out:
# 405
